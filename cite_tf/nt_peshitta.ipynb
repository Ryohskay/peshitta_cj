# %%
# !pip install text-fabric

# %%
import os
import collections
from tf.app import use


api_handler = use("etcbc/syrnt", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#gdae3eb6ff62b9b272fb503646796c25d248175ce offline under /Users/ryohskay/text-fabric-data/github">~/text-fabric-data/github/etcbc/syrnt/app</span>
# <b title="local commit">data:</b> <span title="#gdae3eb6ff62b9b272fb503646796c25d248175ce offline under /Users/ryohskay/text-fabric-data/github">~/text-fabric-data/github/etcbc/syrnt/tf/0.1</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.6.4</a>, <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/app" title="etcbc/syrnt app">etcbc/syrnt/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
i = 0
for n in N.walk():
    i += 1

api_handler.info("{} nodes".format(i))
# Out:
#   3.60s 120922 nodes

# %%
F.otype.slotType
# Out:
# 'word'

# %%
api_handler.indent(reset=True)
api_handler.info("counting objects ...")

for otype in F.otype.all:
    i = 0
    api_handler.indent(level=1, reset=True)

    for n in F.otype.s(otype):
        i += 1

    api_handler.info("{:>7} {}s".format(i, otype))

api_handler.indent(level=0)
# Out:
#   0.00s counting objects ...
#    |     0.00s      27 books
#    |     0.00s     260 chapters
#    |     0.00s    3038 lexemes
#    |     0.00s    7957 verses
#    |     0.03s  109640 words

# %%
Fall()
# Out:
# ['book',
#  'book@en',
#  'chapter',
#  'demcat',
#  'fmhdot',
#  'gn',
#  'lexeme',
#  'lexeme_etcbc',
#  'lexeme_sedra',
#  'nmtyp',
#  'ntyp',
#  'nu',
#  'otype',
#  'prefix',
#  'prefix_etcbc',
#  'prefix_sedra',
#  'prtyp',
#  'ps',
#  'ptctyp',
#  'root',
#  'root_etcbc',
#  'root_sedra',
#  'seyame',
#  'sfcontract',
#  'sfgn',
#  'sfnu',
#  'sfps',
#  'sp',
#  'st',
#  'stem',
#  'stem_etcbc',
#  'stem_sedra',
#  'suffix',
#  'suffix_etcbc',
#  'suffix_sedra',
#  'verse',
#  'vs',
#  'vt',
#  'word',
#  'word_etcbc',
#  'word_sedra']

# %%
F

# %%
for book in F.otype.s("book"):
    print(T.text())
# Out:
# ܟܬܒܐ ܕܝܠܝܕܘܬܗ ܕܝܫܘܥ ܡܫܝܚܐ ܒܪܗ ܕܕܘܝܕ ܒܪܗ ܕܐܒܪܗܡ ܐܒܪܗܡ ܐܘܠܕ ܠܐܝܣܚܩ ܐܝܣܚܩ ܐܘܠܕ ܠܝܥܩܘܒ ܝܥܩܘܒ ܐܘܠܕ ܠܝܗܘܕܐ ܘܠܐܚܘܗܝ ܝܗܘܕܐ ܐܘܠܕ ܠܦܪܨ ܘܠܙܪܚ ܡܢ ܬܡܪ ܦܪܨ ܐܘܠܕ ܠܚܨܪܘܢ ܚܨܪܘܢ ܐܘܠܕ ܠܐܪܡ ܐܪܡ ܐܘܠܕ ܠܥܡܝܢܕܒ ܥܡܝܢܕܒ ܐܘܠܕ ܠܢܚܫܘܢ ܢܚܫܘܢ ܐܘܠܕ ܠܣܠܡܘܢ ܣܠܡܘܢ ܐܘܠܕ ܠܒܥܙ ܡܢ ܪܚܒ ܒܥܙ ܐܘܠܕ ܠܥܘܒܝܕ ܡܢ ܪܥܘܬ ܥܘܒܝܕ �
#  ('HW>', 1535),
#  ('>N>', 1361),
#  ('GJR', 1085),
#  ('<L', 909),
#  ('>MR', 885),
#  ('JCW<', 848),
#  ('LHWN', 830),
#  ('HWW', 815),
#  ('>L>', 784),
#  ('>NTWN', 780),
#  ('WL>', 732),
#  ('KD', 730),
#  ('DL>', 720),
#  ('>JK', 681),
#  ('LKWN', 676),
#  ('W>MR', 651),
#  ('MVL', 632),
#  ('D>LH>', 586),
#  ('>P', 544),
#  ('>LH>', 497),
#  ('>NT', 491),
#  ('HN>', 482),
#  ('>NWN', 462),
#  ('HLJN', 451),
#  ('LJ', 440),
#  ('WKD', 429),
#  ('>N', 417),
#  ('XD', 412),
#  ('MCJX>', 404),
#  ('HJ', 403),
#  ('MDM', 403),
#  ('BH', 343),
#  ('>JT', 330),
#  ('HD>', 325),
#  ('>NC', 323),
#  ('>JLJN', 319),
#  ('HNWN', 314),
#  ('>W', 312),
#  ('WMN', 285),
#  ('KL', 280),
#  ('LK', 269),
#  ('LN', 263),
#  ('>JKN>', 261),
#  ('DMN', 259),
#  ('MN>', 257),
#  ('<M', 250),
#  ('HKJL', 250),
#  ('HWT', 248),
#  ('LWT', 245),
#  ('>T>', 243),
#  ('SGJ>>', 230),
#  ('D>JT', 229),
#  ('HKN>', 220),
# ...

# %%
type(F.book.items())
# Out:
# dict_items

# %%
Fall()
# Out:
# ['book',
#  'book@en',
#  'chapter',
#  'demcat',
#  'fmhdot',
#  'gn',
#  'lexeme',
#  'lexeme_etcbc',
#  'lexeme_sedra',
#  'nmtyp',
#  'ntyp',
#  'nu',
#  'otype',
#  'prefix',
#  'prefix_etcbc',
#  'prefix_sedra',
#  'prtyp',
#  'ps',
#  'ptctyp',
#  'root',
#  'root_etcbc',
#  'root_sedra',
#  'seyame',
#  'sfcontract',
#  'sfgn',
#  'sfnu',
#  'sfps',
#  'sp',
#  'st',
#  'stem',
#  'stem_etcbc',
#  'stem_sedra',
#  'suffix',
#  'suffix_etcbc',
#  'suffix_sedra',
#  'verse',
#  'vs',
#  'vt',
#  'word',
#  'word_etcbc',
#  'word_sedra']

# %%
for items in Fs("vt").items():
    # if items[1] not in {"NA", "cardinal"}:
    print(items)
# Out:
# (1, 'NA')
# (2, 'NA')
# (3, 'NA')
# (4, 'NA')
# (5, 'NA')
# (6, 'NA')
# (7, 'NA')
# (8, 'NA')
# (9, 'NA')
# (10, 'perfect')
# (11, 'NA')
# (12, 'NA')
# (13, 'perfect')
# (14, 'NA')
# (15, 'NA')
# (16, 'perfect')
# (17, 'NA')
# (18, 'NA')
# (19, 'NA')
# (20, 'perfect')
# (21, 'NA')
# (22, 'NA')
# (23, 'NA')
# (24, 'NA')
# (25, 'NA')
# (26, 'perfect')
# (27, 'NA')
# (28, 'NA')
# (29, 'perfect')
# (30, 'NA')
# (31, 'NA')
# (32, 'perfect')
# (33, 'NA')
# (34, 'NA')
# (35, 'perfect')
# (36, 'NA')
# (37, 'NA')
# (38, 'perfect')
# (39, 'NA')
# (40, 'NA')
# (41, 'perfect')
# (42, 'NA')
# (43, 'NA')
# (44, 'NA')
# (45, 'NA')
# (46, 'perfect')
# (47, 'NA')
# (48, 'NA')
# (49, 'NA')
# (50, 'NA')
# (51, 'perfect')
# (52, 'NA')
# (53, 'NA')
# (54, 'perfect')
# (55, 'NA')
# (56, 'NA')
# (57, 'NA')
# (58, 'perfect')
# (59, 'NA')
# (60, 'NA')
# (61, 'NA')
# (62, 'NA')
# (63, 'NA')
# (64, 'perfect')
# (65, 'NA')
# (66, 'NA')
# (67, 'perfect')
# (68, 'NA')
# (69, 'NA')
# (70, 'perfect')
# (71, 'NA')
# ...

# %%
word_id = 5
print(F.word.v(word_id))
print(F.word_etcbc.v(word_id))
print(F.prefix_etcbc.v(word_id))
print(F.lexeme_etcbc.v(word_id))
print(F.root_etcbc.v(word_id))

book_words = []
ve = L.u(word_id, "verse")
print(ve)
ch = L.u(ve[0], "chapter")
print(ch)
bo = L.u(ch[0], "book")

print(f"{F.book.v(bo[0])}, {F.chapter.v(ch[0])}:{F.verse.v(ve[0])}")

for lex_id in range(190,210):
    book_words.append(F.word_etcbc.v(lex_id))

print(book_words)
# Out:
# ܒܪܗ
# BRH
#
# BR>
# BR
# (112966,)
# (109668,)
# Matt, 1:1
# ['>CTKXT', 'BVN>', 'MN', 'RWX>', 'DQWDC>', 'JWSP', 'DJN', 'B<LH', 'K>N>', 'HW>', 'WL>', 'YB>', 'DNPRSJH', 'W>TR<J', 'HW>', 'DMVCJ>JT', 'NCRJH', 'KD', 'HLJN', 'DJN']

# %%
def lemmatise(w_id: int) -> tuple:
    root = F.root_etcbc.v(w_id)
    prefix = F.prefix_etcbc.v(w_id)
    if prefix != "":
        return (prefix, root)
    else:
        return (root,)

# %%
from pathlib import Path

# %%
target_books = {
    'Matthew': [],
    'Mark': [],
    'Luke': [],
    'John': []
}

# %%
for book in Fs("book@en").items():
    if book[1] in target_books.keys():
        print(f"Book: {book[1]}\n")
        chapters = L.d(book[0], otype="chapter")
        chap = chapters[1]
        verses = L.d(chap, otype="verse")
        vrs = verses[13]
        words = L.d(vrs, otype="word")
        
        for w_id in words:
            word = F.word_etcbc.v(w_id)
            prefix = F.prefix_etcbc.v(w_id)
            stem = F.stem_etcbc.v(w_id)
            root = F.root_etcbc.v(w_id)
            lexeme = F.lexeme_etcbc.v(w_id)
            if prefix != "":
                print(f"{word}\n\tPREFIX: {prefix}\n\tSTEM: {stem}; ROOT: {root}; LEXEME: {lexeme}")
            else:
                print(f"{word}\n\tSTEM: {stem}; ROOT: {root}; LEXEME: {lexeme}")
# Out:
# Book: Matthew
#
# JWSP
# 	STEM: JWSP; ROOT: JWSP; LEXEME: JWSP
# DJN
# 	STEM: DJN; ROOT: DJN; LEXEME: DJN
# QM
# 	STEM: QM; ROOT: QM; LEXEME: QM
# CQLH
# 	STEM: CQL; ROOT: CQL; LEXEME: CQL
# LVLJ>
# 	PREFIX: L
# 	STEM: VLJ>; ROOT: VLJ>; LEXEME: VLJ>
# WL>MH
# 	PREFIX: WL
# 	STEM: >M; ROOT: >M; LEXEME: >M>
# BLLJ>
# 	PREFIX: B
# 	STEM: LLJ>; ROOT: LJLJ; LEXEME: LLJ>
# W<RQ
# 	PREFIX: W
# 	STEM: <RQ; ROOT: <RQ; LEXEME: <RQ
# LMYRJN
# 	PREFIX: L
# 	STEM: MYRJN; ROOT: MYRJN; LEXEME: MYRJN
# Book: Mark
#
# WKD
# 	PREFIX: W
# 	STEM: KD; ROOT: KD; LEXEME: KD
# <BR
# 	STEM: <BR; ROOT: <BR; LEXEME: <BR
# XZ>
# 	STEM: XZ>; ROOT: XZ>; LEXEME: XZ>
# LLWJ
# 	PREFIX: L
# 	STEM: LWJ; ROOT: LWJ; LEXEME: LWJ
# BR
# 	STEM: BR; ROOT: BR; LEXEME: BR>
# XLPJ
# 	STEM: XLPJ; ROOT: XLPJ; LEXEME: XLPJ
# DJTB
# 	PREFIX: D
# 	STEM: JTB; ROOT: JTB; LEXEME: JTB
# BJT
# 	STEM: BJT; ROOT: BT; LEXEME: BJT>
# MKS>
# 	STEM: MKS>; ROOT: MKS>; LEXEME: MKS>
# W>MR
# 	PREFIX: W
# 	STEM: >MR; ROOT: >MR; LEXEME: >MR
# LH
# ...

# %%
for book in Fs("book@en").items():
    # if book[1] in target_books.keys():
    # print(f"\nBook: {book[1]}\n")
    # save_file = Path(f"./out/etcbc_{book[1]}_roots_results.csv")
    
    chapters = L.d(book[0], otype="chapter")
    results = "Verse Reference,Lemmatised Transliteration,Plain Transliteration,Original Syriac Text\n"

    # lemmata = []
    verse_words = []
    all_text = []

    for chapter in chapters:
        for verse in L.d(chapter, otype="verse"):
            verse_ref = f"Chapter {F.chapter.v(chapter)} Verse {F.verse.v(verse)}"
            # Get all words in this verse
            words = L.d(verse, otype="word")
            # Lemmatised text of this verse, in transliterated form
            # lemmata.extend([lemma for w_id in words for lemma in lemmatise(w_id)])
            # verse_lemmata = ' '.join(lemmata)
            # Transliteration of this verse as a list of words
            translit_words = [F.word_etcbc.v(w_id) for w_id in words]
            verse_words.append(translit_words)
            all_text.extend(translit_words)
            # Same verse in Syriac alphabet
            # words_src = [F.word.v(w_id) for w_id in words]
            # verse_src = ' '.join(words_src)
            # print(f"{verse_ref}\n\t{verse_lemmata}\t{verse_text}\n\t{verse_src}")
            # results += f"{verse_ref},{verse_lemmata},{verse_text},{verse_src}\n"

    # save_file.write_text(results)
1 
    print(f"{book[1]}:\t{len(all_text)}")
# Out:
# Matthew:	13979
# Mark:	8793
# Luke:	15234
# John:	12408
# Acts:	15383
# Romans:	5768
# 1_Corinthians:	5986
# 2_Corinthians:	3737
# Galatians:	1940
# Ephesians:	1774
# Philippians:	1326
# Colossians:	1133
# 1_Thessalonians:	1117
# 2_Thessalonians:	609
# 1_Timothy:	1507
# 2_Timothy:	1040
# Titus:	644
# Philemon:	277
# Hebrews:	4288
# James:	1444
# 1_Peter:	1535
# 2_Peter:	1028
# 1_John:	1547
# 2_John:	197
# 3_John:	211
# Jude:	415
# Revelation:	6320
